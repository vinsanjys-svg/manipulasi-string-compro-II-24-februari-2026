# %% [markdown]
# **Nama : Fara Kamila**
# **NPM : 2411012043**

# %%
# !pip install pyTelegramBotAPI
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 4.7 MB/s eta 0:00:00
# ...

# %%
import telebot
import requests

TOKEN = "8315199157:AAHfZ10k-MKjoIbFF24_MXlZxKKKktw-47c"
bot = telebot.TeleBot("8315199157:AAHfZ10k-MKjoIbFF24_MXlZxKKKktw-47c")

@bot.message_handler(commands=['start'])
def start(message):
  bot.reply_to(message, "Halo! Bot aktif.")

def get_quote():
  url = "https://quotes.liupurnomo.com/api/quotes/random"
  data = requests.get(url).json()
  return data["data"]["text"]

@bot.message_handler(commands=['quote'])
def quote(message):
  bot.reply_to(message, get_quote())

def get_jokes_bapak():
  url = "https://candaan-api.vercel.app/api/text/random"
  data = requests.get(url).json()
  return data["data"]

@bot.message_handler(commands=['jokesbapak'])
def jokesbapak(message):
  bot.reply_to(message, get_jokes_bapak())

@bot.message_handler(commands=['siapakamu'])
def siapakamu(message):
  bot.reply_to(message, "Hai! Aku FleurrytieBot buatan Fara Kamila dengan NPM 2411012043, salam kenal ya!")

bot.infinity_polling()
# Out:
# 2026-05-05 07:50:37,855 (__init__.py:1134 MainThread) ERROR - TeleBot: "Infinity polling: polling exited"
# ERROR:TeleBot:Infinity polling: polling exited
# 2026-05-05 07:50:37,857 (__init__.py:1136 MainThread) ERROR - TeleBot: "Break infinity polling"
# ERROR:TeleBot:Break infinity polling
